# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns
import re,nltk

# %%
#read the dataset
data = pd.read_excel('/content/drive/MyDrive/consumer/Dataset_2/data.xlsx')
data
# Out:
#                                        Comments     Class
# 0     আমি দারাজ  থেকে এই পণ্য কিনে সন্তুষ্ট 👌👍😍  Positive
# 1                             কর্মক্ষমতা ভাল না  Negative
# 2                    আমি দারাজ এর কাছে  কৃতজ্ঞ।  Positive
# 3                      এটা অবশ্যই খুব ভাল পণ্য   Positive
# 4     সম্পূর্ণ সন্তুষ্ট .... সত্যিই চিত্তাকর্ষক  Positive
# ...                                         ...       ...
# 2203                        গুনগত মান ভা‌লো না  Negative
# 2204                        খুবি চমৎকার টিশার্ট  Positive
# 2205                        কাপড় খুবই পাতলা ছিল  Negative
# 2206                      কাপ‌ড়ের মান ভা‌লো না  Negative
# 2207                  টি-শার্টগুলো খুবই সুন্দর   Positive
#
# [2208 rows x 2 columns]

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2208 entries, 0 to 2207
# Data columns (total 2 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Comments  2208 non-null   object
#  1   Class     2208 non-null   object
# dtypes: object(2)
# memory usage: 34.6+ KB

# %%
data.groupby('Class').size().reset_index(name='counts')
# Out:
#       Class  counts
# 0  Negative     940
# 1  Positive    1268

# %%
#Define the function for cleaning the data
def process_text(text): 
    text = re.sub('[^\u0980-\u09FF]',' ',text)
    text = re.sub('[?.`*^()!°¢܌Ͱ̰ߒנ~×Ҡߘ:ҰߑÍ|।;!,&%\'@#$><A-Za-z0+-9=./''""_০-৯]', '', text)
    text = re.sub(r'(\W)(?=\1)', '', text)
    text = re.sub(r'https?:\/\/.*[\r\n]*', '', text, flags=re.MULTILINE)
    text = re.sub(r'\<a href', ' ', text)
    text = re.sub(r'&amp;', '', text) 
    text = re.sub(r'<br />', ' ', text)
    text = re.sub(r'\'', ' ', text)
    text = re.sub(r'ߑͰߑ̰ߒנ', '', text)
    text = re.sub(r'ߎɰߎɰߎɍ', '', text)
    return text

# %%
data['cleaned_text'] = data['Comments'].apply(process_text)  
data
# Out:
#                                        Comments     Class  \
# 0     আমি দারাজ  থেকে এই পণ্য কিনে সন্তুষ্ট 👌👍😍  Positive
# 1                             কর্মক্ষমতা ভাল না  Negative
# 2                    আমি দারাজ এর কাছে  কৃতজ্ঞ।  Positive
# 3                      এটা অবশ্যই খুব ভাল পণ্য   Positive
# 4     সম্পূর্ণ সন্তুষ্ট .... সত্যিই চিত্তাকর্ষক  Positive
# ...                                         ...       ...
# 2203                        গুনগত মান ভা‌লো না  Negative
# 2204                        খুবি চমৎকার টিশার্ট  Positive
# 2205                        কাপড় খুবই পাতলা ছিল  Negative
# 2206                      কাপ‌ড়ের মান ভা‌লো না  Negative
# 2207                  টি-শার্টগুলো খুবই সুন্দর   Positive
#
#                                cleaned_text
# 0     আমি দারাজ থেকে এই পণ্য কিনে সন্তুষ্ট
# 1                         কর্মক্ষমতা ভাল না
# 2                 আমি দারাজ এর কাছে কৃতজ্ঞ
# 3                  এটা অবশ্যই খুব ভাল পণ্য
# 4      সম্পূর্ণ সন্তুষ্ট সত্যিই চিত্তাকর্ষক
# ...                                     ...
# 2203                    গুনগত মান ভা লো না
# 2204                    খুবি চমৎকার টিশার্ট
# 2205                    কাপড় খুবই পাতলা ছিল
# 2206                  কাপ ড়ের মান ভা লো না
# 2207              টি শার্টগুলো খুবই সুন্দর
#
# [2208 rows x 3 columns]

# %%
stopwords_list ='/content/drive/MyDrive/consumer/Dataset_2/stopwords-bn.txt'

# %%
# Stopwords Removal
def stopword_removal(Comment,stopwords= stopwords_list):
    stp,num_of_stopwords =stopwords_info(stopwords)
    result = Comment.split()
    Comments = [word.strip() for word in result if word not in stp ]
    Comments =" ".join(Comments)
    return Comments

def stopwords_info(filename):
    stp = open(filename,'r',encoding='utf-8').read().split()
    num_of_stopwords = len(stp)
    return stp,num_of_stopwords
    return text

# %%
data['cleaned_text'] = data['cleaned_text'].apply(stopword_removal)  
data
# Out:
#                                        Comments     Class  \
# 0     আমি দারাজ  থেকে এই পণ্য কিনে সন্তুষ্ট 👌👍😍  Positive
# 1                             কর্মক্ষমতা ভাল না  Negative
# 2                    আমি দারাজ এর কাছে  কৃতজ্ঞ।  Positive
# 3                      এটা অবশ্যই খুব ভাল পণ্য   Positive
# 4     সম্পূর্ণ সন্তুষ্ট .... সত্যিই চিত্তাকর্ষক  Positive
# ...                                         ...       ...
# 2203                        গুনগত মান ভা‌লো না  Negative
# 2204                        খুবি চমৎকার টিশার্ট  Positive
# 2205                        কাপড় খুবই পাতলা ছিল  Negative
# 2206                      কাপ‌ড়ের মান ভা‌লো না  Negative
# 2207                  টি-শার্টগুলো খুবই সুন্দর   Positive
#
#                               cleaned_text
# 0                 দারাজ পণ্য কিনে সন্তুষ্ট
# 1                        কর্মক্ষমতা ভাল না
# 2                             দারাজ কৃতজ্ঞ
# 3                          অবশ্যই ভাল পণ্য
# 4     সম্পূর্ণ সন্তুষ্ট সত্যিই চিত্তাকর্ষক
# ...                                    ...
# 2203                   গুনগত মান ভা লো না
# 2204                   খুবি চমৎকার টিশার্ট
# 2205                       কাপড় খুবই পাতলা
# 2206                 কাপ ড়ের মান ভা লো না
# 2207                 শার্টগুলো খুবই সুন্দর
#
# [2208 rows x 3 columns]

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2208 entries, 0 to 2207
# Data columns (total 3 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Comments      2208 non-null   object
#  1   Class         2208 non-null   object
#  2   cleaned_text  2208 non-null   object
# dtypes: object(3)
# memory usage: 51.9+ KB

# %%
data
# Out:
#                                        Comments     Class  \
# 0     আমি দারাজ  থেকে এই পণ্য কিনে সন্তুষ্ট 👌👍😍  Positive
# 1                             কর্মক্ষমতা ভাল না  Negative
# 2                    আমি দারাজ এর কাছে  কৃতজ্ঞ।  Positive
# 3                      এটা অবশ্যই খুব ভাল পণ্য   Positive
# 4     সম্পূর্ণ সন্তুষ্ট .... সত্যিই চিত্তাকর্ষক  Positive
# ...                                         ...       ...
# 2203                        গুনগত মান ভা‌লো না  Negative
# 2204                        খুবি চমৎকার টিশার্ট  Positive
# 2205                        কাপড় খুবই পাতলা ছিল  Negative
# 2206                      কাপ‌ড়ের মান ভা‌লো না  Negative
# 2207                  টি-শার্টগুলো খুবই সুন্দর   Positive
#
#                               cleaned_text
# 0                 দারাজ পণ্য কিনে সন্তুষ্ট
# 1                        কর্মক্ষমতা ভাল না
# 2                             দারাজ কৃতজ্ঞ
# 3                          অবশ্যই ভাল পণ্য
# 4     সম্পূর্ণ সন্তুষ্ট সত্যিই চিত্তাকর্ষক
# ...                                    ...
# 2203                   গুনগত মান ভা লো না
# 2204                   খুবি চমৎকার টিশার্ট
# 2205                       কাপড় খুবই পাতলা
# 2206                 কাপ ড়ের মান ভা লো না
# 2207                 শার্টগুলো খুবই সুন্দর
#
# [2208 rows x 3 columns]

# %%
#Save the cleaned data to a new file
data.to_excel('/content/drive/MyDrive/consumer/Dataset_2/dataset_clean.xlsx')
